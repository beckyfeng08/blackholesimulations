# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib inline
# %matplotlib notebook

# %%
#setting up parameters
#all in SI
G = 6.67*10**(-11)
M = 6*10**30 #idk, stereotypical mass of three solar masses i guess
c = 3*10**8 

#feel free to vary this
r_s = 2*G*M/c**2

# %% [markdown]
# ## Photon trajectory in the radial direction

# %%
#calculating r at all timesteps
r = 10000
rlist = [r]

def getdr_dt(r):
    return c*(1-r_s/r)

for t in range(200):
    v = getv(r)
    r_new = r - v*0.000003
    if r_new <= r_s:
        break
    rlist.append(r_new)
    r = r_new
    prevv = v
yvals = [0]*len(rlist)

# %%
#plotting
fig, ax = plt.subplots()
ax.set_xlim(min(rlist) - 500, max(rlist) + 500)
animated_plot1, = ax.plot([],[], label="position of photon")

r = np.linspace(min(rlist) - 500, max(rlist) + 500,100)
velocity = c*(1-r_s/r)

ax.plot(r, velocity, label="velocity of photon")

ax.vlines(r_s, -2*10**7, 4*10**7, label = "schwarzschild radius", color="green")

ax.title.set_text('Trajectory of a Photon Moving Radially Towards a  \n Black Hole of 3 Solar Masses (timestep: 0.000003 seconds)')
ax.set_ylabel('(Yellow) Velocity of Photon (m/s)')
ax.set_xlabel("Radial Distance Between Photon and Black Hole (m)")
plt.legend()
plt.show()

#animation
def animate(frame):
    animated_plot1.set_data(rlist[:frame], yvals[:frame])
    return animated_plot1

ani = animation.FuncAnimation(fig = fig, func = animate, repeat=True,
                                    frames= len(rlist), interval=50)
# Out:
# <img src="data:image/png;base64,..." width="431.5">

# %% [markdown]
# ## Photon trajectory in the angular direction

# %%
def populate(currtheta, numthetas = 100, r = 10000):
    returnlist = [currtheta]
    dtheta_dt = np.sqrt(1-r_s/r)*c/r
    print(dtheta_dt)
    delta_t = 0.000003
    for i in range(numthetas):
        newtheta = (currtheta + dtheta_dt*delta_t)%(2*np.pi)
        returnlist.append(newtheta)
        currtheta = newtheta
    return returnlist

r = 10000 #feel free to change this


theta = 0 #to start
listtheta = populate(theta,100, r)
print(listtheta)
# Out:
# 9979.979959899716
# [0, 0.02993993987969915, 0.0598798797593983, 0.08981981963909745, 0.1197597595187966, 0.14969969939849576, 0.1796396392781949, 0.20957957915789405, 0.2395195190375932, 0.26945945891729234, 0.2993993987969915, 0.3293393386766907, 0.35927927855638986, 0.38921921843608903, 0.4191591583157882, 0.4490990981954874, 0.47903903807518655, 0.5089789779548857, 0.5389189178345848, 0.5688588577142839, 0.598798797593983, 0.6287387374736821, 0.6586786773533813, 0.6886186172330804, 0.7185585571127795, 0.7484984969924786, 0.7784384368721777, 0.8083783767518768, 0.838318316631576, 0.8682582565112751, 0.8981981963909742, 0.9281381362706733, 0.9580780761503724, 0.9880180160300716, 1.0179579559097707, 1.0478978957894698, 1.077837835669169, 1.107777775548868, 1.1377177154285671, 1.1676576553082663, 1.1975975951879654, 1.2275375350676645, 1.2574774749473636, 1.2874174148270627, 1.3173573547067619, 1.347297294586461, 1.37723723446616, 1.4071771743458592, 1.4371171142255583, 1.4670570541052574, 1.4969969939849566, 1.5269369338646557, 1.5568768737443548, 1.586816813624054, 1.616756753503753, 1.6466966933834521, 1.6766366332631513, 1.7065765731428504, 1.7365165130225495, 1.7664564529022486, 1.7963963927819477, 1.8263363326616469, 1.856276272541346, 1.886216212421045, 1.9161561523007442, 1.9460960921804433, 1.9760360320601424, 2.005975971939842, 2.035915911819541, 2.06585585169924, 2.095795791578939, 2.1257357314586383, 2.1556756713383374, 2.1856156112180365, 2.2155555510977356, 2.2454954909774347, 2.275435430857134, 2.305375370736833, 2.335315310616532, 2.365255250496231, 2.3951951903759303, 2.4251351302556294, 2.4550750701353286, 2.4850150100150277, 2.514954949894727, 2.544894889774426, 2.574834829654125, 2.604774769533824, 2.6347147094135233, 2.6646546492932224, 2.6945945891729215, 2.7245345290526206, 2.7544744689323197, 2.784414408812019, 2.814354348691718, 2.844294288571417, 2.874234228451116, 2.9041741683308153, 2.9341141082105144, 2.9640540480902136, 2.9939939879699127]
